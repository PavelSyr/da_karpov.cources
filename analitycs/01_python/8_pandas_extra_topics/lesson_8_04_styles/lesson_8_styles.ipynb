# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(77)
df = pd.DataFrame({'A': list(range(5)), 
                   'B': np.random.randint(0, 10, 5),
                   'C': np.random.randint(-10, 10, 5), 
                   'D': np.random.randint(-10, 100, 5)})
df
# Out:
#    A  B   C   D
# 0  0  7 -10  49
# 1  1  4  -3  90
# 2  2  4   2  44
# 3  3  5   9  26
# 4  4  8 -10  37

# %% [markdown]
# <h2>индексы и подписи</h2>

# %%
df.style.hide_index() \
.set_caption('Test capture')
# Out:
# <style  type="text/css" >
# </style><table id="T_4fb60_" ><caption>Test capture</caption><thead>    <tr>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_4fb60_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_4fb60_row0_col1" class="data row0 col1" >7</td>
#                         <td id="T_4fb60_row0_col2" class="data row0 col2" >-10</td>
#                         <td id="T_4fb60_row0_col3" class="data row0 col3" >49</td>
#             </tr>
#             <tr>
#                                 <td id="T_4fb60_row1_col0" class="data row1 col0" >1</td>
#                         <td id="T_4fb60_row1_col1" class="data row1 col1" >4</td>
# ...

# %% [markdown]
# <h2>раскрашиваем ячейки</h2>

# %%
# df.style.highlight_max(axis='columns')
# df.style.highlight_max(axis=0)

# df.style.highlight_max(axis='index')
# df.style.highlight_max(axis=1, color='orange')
# Out:
# <style  type="text/css" >
# #T_f3f93_row0_col3,#T_f3f93_row1_col3,#T_f3f93_row2_col3,#T_f3f93_row3_col3,#T_f3f93_row4_col3{
#             background-color:  orange;
#         }</style><table id="T_f3f93_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f3f93_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_f3f93_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_f3f93_row0_col1" class="data row0 col1" >7</td>
#                         <td id="T_f3f93_row0_col2" class="data row0 col2" >-10</td>
#                         <td id="T_f3f93_row0_col3" class="data row0 col3" >49</td>
#             </tr>
#             <tr>
# ...

# %%
df.style.highlight_max(axis=0, color='orange') \
    .highlight_min(axis=1)
# Out:
# <style  type="text/css" >
# #T_3f496_row0_col2,#T_3f496_row1_col2,#T_3f496_row2_col0,#T_3f496_row2_col2,#T_3f496_row3_col0,#T_3f496_row4_col2{
#             background-color:  yellow;
#         }#T_3f496_row1_col3,#T_3f496_row3_col2,#T_3f496_row4_col0,#T_3f496_row4_col1{
#             background-color:  orange;
#         }</style><table id="T_3f496_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3f496_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_3f496_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_3f496_row0_col1" class="data row0 col1" >7</td>
# ...

# %% [markdown]
# <h2>форматирование отображения чисел</h2>

# %%
df = pd.DataFrame({'A': np.linspace(1, 10, 5)})
df = pd.concat([df, pd.DataFrame(np.random.randn(5, 4), columns=list('BCDE'))],axis=1)
df['F'] = np.random.choice(['A', 'B'], size=5)
df.iloc[3, 3] = np.nan 
df.iloc[0, 2] = np.nan 
df
# Out:
#        A         B         C         D         E  F
# 0   1.00  0.797939       NaN -1.652119  0.717119  B
# 1   3.25  0.977228 -1.040849 -0.643520 -0.112520  A
# 2   5.50 -0.314166  1.627440 -0.361227 -0.173046  B
# 3   7.75 -1.951309 -0.978210       NaN -1.178379  A
# 4  10.00 -0.515551 -0.063015 -0.559371  0.796697  A

# %% [markdown]
# Форматируем:
#
# оставляем только 2 знака после точки
# добавляем знак + для положительных значений
# применяем ко всем колонкам, кроме F

# %%
df.style.format("{:+.2f}", subset=df.columns.drop('F'))
# Out:
# <style  type="text/css" >
# </style><table id="T_e15bc_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e15bc_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e15bc_row0_col0" class="data row0 col0" >+1.00</td>
#                         <td id="T_e15bc_row0_col1" class="data row0 col1" >+0.80</td>
#                         <td id="T_e15bc_row0_col2" class="data row0 col2" >+nan</td>
#                         <td id="T_e15bc_row0_col3" class="data row0 col3" >-1.65</td>
# ...

# %% [markdown]
# Также можем скрыть индексы и добавить название:

# %%
(df.style
 .format({'B': "{:0<4.0f}", 'D': '{:+.2f}'})
 .hide_index()
 .set_caption('Новая таблица'))
# Out:
# <style  type="text/css" >
# </style><table id="T_7140f_" ><caption>Новая таблица</caption><thead>    <tr>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                                 <td id="T_7140f_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_7140f_row0_col1" class="data row0 col1" >1000</td>
#                         <td id="T_7140f_row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_7140f_row0_col3" class="data row0 col3" >-1.65</td>
#                         <td id="T_7140f_row0_col4" class="data row0 col4" >0.717119</td>
#                         <td id="T_7140f_row0_col5" class="data row0 col5" >B</td>
# ...

# %%
df.style.format({'B': "{:0<0.0f}"})
# Out:
# <style  type="text/css" >
# </style><table id="T_d6b44_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A</th>        <th class="col_heading level0 col1" >B</th>        <th class="col_heading level0 col2" >C</th>        <th class="col_heading level0 col3" >D</th>        <th class="col_heading level0 col4" >E</th>        <th class="col_heading level0 col5" >F</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d6b44_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_d6b44_row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_d6b44_row0_col1" class="data row0 col1" >1</td>
#                         <td id="T_d6b44_row0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_d6b44_row0_col3" class="data row0 col3" >-1.652119</td>
# ...

# %%
df.style.bar(align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_f93a1_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 10.0%, transparent 10.0%);
#         }#T_f93a1_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 66.6%, #5fba7d 66.6%, #5fba7d 93.9%, transparent 93.9%);
#         }#T_f93a1_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_f93a1_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 59.7%, #5fba7d 59.7%, #5fba7d 96.0%, transparent 96.0%);
#         }#T_f93a1_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 32.5%, transparent 32.5%);
#         }#T_f93a1_row1_col1{
# ...

# %%
df.style.bar(align='zero', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_6630f_row0_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 55.0%, transparent 55.0%);
#         }#T_6630f_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 70.4%, transparent 70.4%);
#         }#T_6630f_row0_col3,#T_6630f_row3_col1,#T_6630f_row3_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.0%, transparent 50.0%);
#         }#T_6630f_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 50.0%, #5fba7d 50.0%, #5fba7d 80.4%, transparent 80.4%);
#         }#T_6630f_row1_col0{
#             width:  10em;
#              height:  80%;
# ...

# %%
df.style.bar(align='left', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_6af4b_row0_col0,#T_6af4b_row0_col3,#T_6af4b_row1_col2,#T_6af4b_row3_col1,#T_6af4b_row3_col4{
#             width:  10em;
#              height:  80%;
#         }#T_6af4b_row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 93.9%, transparent 93.9%);
#         }#T_6af4b_row0_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 96.0%, transparent 96.0%);
#         }#T_6af4b_row1_col0{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 25.0%, transparent 25.0%);
#         }#T_6af4b_row1_col1,#T_6af4b_row2_col2,#T_6af4b_row4_col0,#T_6af4b_row4_col4{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#5fba7d 100.0%, transparent 100.0%);
#         }#T_6af4b_row1_col3{
#             width:  10em;
# ...

# %% [markdown]
# <h2>Retantion</h2>

# %%
# df = pd.read_csv("https://stepik.org/media/attachments/lesson/367416/user_retention.csv", index_col=0)
df = pd.read_csv('user_retention.csv', index_col=0)

# %%
df
# Out:
#            0         1         2         3         4         5         6  \
# Cohort
# 2010-12  1.0  0.381857  0.334388  0.387131  0.359705  0.396624  0.379747
# 2011-01  1.0  0.239905  0.282660  0.242280  0.327791  0.299287  0.261283
# 2011-02  1.0  0.247368  0.192105  0.278947  0.268421  0.247368  0.255263
# 2011-03  1.0  0.190909  0.254545  0.218182  0.231818  0.177273  0.263636
# 2011-04  1.0  0.227425  0.220736  0.210702  0.207358  0.237458  0.230769
# 2011-05  1.0  0.236559  0.172043  0.172043  0.215054  0.243728  0.265233
# 2011-06  1.0  0.208511  0.187234  0.272340  0.246809  0.336170  0.102128
# 2011-07  1.0  0.209424  0.204188  0.230366  0.272251  0.115183       NaN
# 2011-08  1.0  0.251497  0.251497  0.251497  0.137725       NaN       NaN
# 2011-09  1.0  0.298658  0.325503  0.120805       NaN       NaN       NaN
# 2011-10  1.0  0.264205  0.130682       NaN       NaN       NaN       NaN
# 2011-11  1.0  0.134375       NaN       NaN       NaN       NaN       NaN
# ...

# %%
ur_style = (df
            .style
            .set_caption('User retention by cohort')  # добавляем подпись
            .background_gradient(cmap='viridis')  # раскрашиваем ячейки по столбцам
            .highlight_null('white')  # делаем белый фон для значений NaN
            .format("{:.2%}", na_rep=""))  # числа форматируем как проценты, NaN заменяем на пустоту
ur_style
# Out:
# <style  type="text/css" >
# #T_4dde8_row0_col0,#T_4dde8_row0_col12,#T_4dde8_row1_col0,#T_4dde8_row1_col11,#T_4dde8_row2_col0,#T_4dde8_row2_col10,#T_4dde8_row3_col0,#T_4dde8_row3_col9,#T_4dde8_row4_col0,#T_4dde8_row4_col8,#T_4dde8_row5_col0,#T_4dde8_row5_col7,#T_4dde8_row6_col0,#T_4dde8_row6_col6,#T_4dde8_row7_col0,#T_4dde8_row7_col5,#T_4dde8_row8_col0,#T_4dde8_row8_col4,#T_4dde8_row9_col0,#T_4dde8_row9_col3,#T_4dde8_row10_col0,#T_4dde8_row10_col2,#T_4dde8_row11_col0,#T_4dde8_row11_col1,#T_4dde8_row12_col0{
#             background-color:  #440154;
#             color:  #f1f1f1;
#         }#T_4dde8_row0_col1,#T_4dde8_row0_col2,#T_4dde8_row0_col3,#T_4dde8_row0_col4,#T_4dde8_row0_col5,#T_4dde8_row0_col6,#T_4dde8_row0_col7,#T_4dde8_row0_col8,#T_4dde8_row0_col9,#T_4dde8_row0_col10,#T_4dde8_row0_col11{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_4dde8_row1_col1{
#             background-color:  #277f8e;
#             color:  #000000;
# ...
